# %%
import pandas as pd

# %%
pd.__file__
# Out:
# '/workspaces/docker_workspace-de_zoomcamp/pipeline/.venv/lib/python3.13/site-packages/pandas/__init__.py'

# %%
PREFIX = "https://github.com/DataTalksClub/nyc-tlc-data/releases/download/yellow"
URL = f"{PREFIX}/yellow_tripdata_2021-01.csv.gz"
df = pd.read_csv(URL)
# Out:
# /tmp/ipykernel_15260/2713901290.py:3: DtypeWarning: Columns (0: store_and_fwd_flag) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(URL)

# %%
df.shape
# Out:
# (1369765, 18)

# %%
dtype = {
    "VendorID": "Int64",
    "passenger_count": "Int64",
    "trip_distance": "float64",
    "RatecodeID": "Int64",
    "store_and_fwd_flag": "string",
    "PULocationID": "Int64",
    "DOLocationID": "Int64",
    "payment_type": "Int64",
    "fare_amount": "float64",
    "extra": "float64",
    "mta_tax": "float64",
    "tip_amount": "float64",
    "tolls_amount": "float64",
    "improvement_surcharge": "float64",
    "total_amount": "float64",
    "congestion_surcharge": "float64"
}

parse_dates = [
    "tpep_pickup_datetime",
    "tpep_dropoff_datetime"
]

df = pd.read_csv(
    URL,
    # nrows=100,
    dtype=dtype,
    parse_dates=parse_dates
)

# %%
df[parse_dates].dtypes
# Out:
# tpep_pickup_datetime     datetime64[us]
# tpep_dropoff_datetime    datetime64[us]
# dtype: object

# %%
from sqlalchemy import create_engine
engine = create_engine('postgresql+psycopg://root:root@localhost:5432/ny_taxi')

# %%
engine.raw_connection
# Out:
# <bound method Engine.raw_connection of Engine(postgresql+psycopg://root:***@localhost:5432/ny_taxi)>

# %%
#alright.,let's carry on and see what happens next

# %%
#Let's get the DDL of the schema
print(pd.io.sql.get_schema(df, name = 'yellow_taxi_data', con = engine))
# Out:
# CREATE TABLE yellow_taxi_data (
# 	"VendorID" BIGINT,
# 	tpep_pickup_datetime TIMESTAMP WITHOUT TIME ZONE,
# 	tpep_dropoff_datetime TIMESTAMP WITHOUT TIME ZONE,
# 	passenger_count BIGINT,
# 	trip_distance FLOAT(53),
# 	"RatecodeID" BIGINT,
# 	store_and_fwd_flag TEXT,
# 	"PULocationID" BIGINT,
# 	"DOLocationID" BIGINT,
# 	payment_type BIGINT,
# 	fare_amount FLOAT(53),
# 	extra FLOAT(53),
# 	mta_tax FLOAT(53),
# 	tip_amount FLOAT(53),
# 	tolls_amount FLOAT(53),
# 	improvement_surcharge FLOAT(53),
# 	total_amount FLOAT(53),
# 	congestion_surcharge FLOAT(53)
# )

# %%
#very good, however, we may not wanna use this, we can also create the table directly from pandas witout using this DDL

df.head(n=0).to_sql(
# Out:
# Empty DataFrame
# Columns: [VendorID, tpep_pickup_datetime, tpep_dropoff_datetime, passenger_count, trip_distance, RatecodeID, store_and_fwd_flag, PULocationID, DOLocationID, payment_type, fare_amount, extra, mta_tax, tip_amount, tolls_amount, improvement_surcharge, total_amount, congestion_surcharge]
# Index: []
